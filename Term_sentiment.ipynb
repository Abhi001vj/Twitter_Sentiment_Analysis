# %%
import sys
import json
def hw():
    print 'Hello, world!'

def lines(fp):
    print str(len(fp.readlines()))

def main():
    sent_file = open("AFINN-111.txt")
    tweet_file = open("three_minutes_tweets.json")
    #afinnfile = open("AFINN-111.txt")
    afinnfile = sent_file
    scores = {}
    for line in afinnfile:
        term , score = line.split("\t")
        scores[term] = int(score)
    #counts = dict()
    sum = 0
    for line in tweet_file:
        js = json.loads(line)
        try:
            text = js["text"]
            wordslst = text.split()
            sum = 0

            for words in wordslst:


                try:

                    sum = sum + scores[words]
                    print words,scores[words]


                except:
                    sum =sum +0

                    #try:
                        #sum = sum + scores[wordslst[i+1]]
                    #except:
                       # sum = sum + scores[wordslst[i-1]]
            for words in wordslst:
                if words not in scores:
                    print words , sum



        except:
            sum = 0
        #print sum
#    for k,v in scores.items():
#        try:
#           ke = k.encode('utf-8')
#           print ke,v
#        except:
#             continue




   #  try:         ke = k.encode('utf-8')
# #           print ke,v
# #       except:
# #           continue










if __name__ == '__main__':


    main()
# Out:
# ايه 0
# الأكل 0
# 😜 0
# RT 0
# @nitishuna: 0
# @LasVegasChicas 0
# @I_luv_reds 0
# @DimondLadies 0
# @SiliconEros 0
# @herby2121 0
# @hughcox69 0
# @VxExx 0
# @Swt_Red 0
# @tthumb9090 0
# @raggdoll_98 0
# http:/… 0
# إنّ 0
# العرب 0
# إذا 0
# تغلبوا 0
# على 0
# أوطان 0
# أسرع 0
# إليها 0
# الخراب 0
# والسبب 0
# في 0
# ذلك 0
# أنها 0
# أمة 0
# وحشية 0
# بإستحكام 0
# عوائد 0
# التوحش 0
# وأسبابه 0
# فصار 0
# لهم 0
# خلقة 0
# وجبلة 0
# - 0
# ابن 0
# خلدون 0
# RT 0
# @moonmona7: 0
# لن 0
# الومك 0
# على 0
# رِحيلك 0
# ... 0
# فَـقٌـدْ 0
# رِحلت 0
# لأٌنـَي 0
# ْ 0
# اَشٌـبَـعـتك 0
# ٌ 0
# حبآ 0
# حـتى 0
# أكتفيت. 0
# .. 0
# http://t.co/ceD9aTiFfI 0
# @16_Pirates 0
# any 0
# shots? 0
# shy -1
# loved 3
# RT 2
# @Cancer_gk: 2
# A 2
# #Cancer 2
# may 2
# act 2
# and 2
# quiet, 2
# but 2
# will 2
# adamantly 2
# defend 2
# a 2
# one 2
# against 2
# outsiders. 2
# thanks 2
# @1voodoochild 2
# for 2
# the 2
# follow💯 2
# "shitting 0
# on 0
# otherkin 0
# is 0
# ablist 0
# and 0
# ...
