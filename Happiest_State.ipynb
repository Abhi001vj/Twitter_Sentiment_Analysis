# %%
import sys
import json
def hw():
    print 'Hello, world!'

def lines(fp):
    print str(len(fp.readlines()))

def main():
    a = raw_input("Enter the state:")
    afinnfile = open("AFINN-111.txt")#read the sentiment file
    tweet_file = open("three_minutes_tweets.json")#read the output.txt
    #afinnfile = sent_file
    #afinnfile = open("AFINN-111.txt")
    scores = {}
    # make a dictionary of the words and sentiment
    for line in afinnfile:
        term , score = line.split("\t")
        scores[term] = int(score)
        # a dictionary for the states
    states = {
        'AK': 'Alaska',
        'AL': 'Alabama',
        'AR': 'Arkansas',
        'AS': 'American Samoa',
        'AZ': 'Arizona',
        'CA': 'California',
        'CO': 'Colorado',
        'CT': 'Connecticut',
        'DC': 'District of Columbia',
        'DE': 'Delaware',
        'FL': 'Florida',
        'GA': 'Georgia',
        'GU': 'Guam',
        'HI': 'Hawaii',
        'IA': 'Iowa',
        'ID': 'Idaho',
        'IL': 'Illinois',
        'IN': 'Indiana',
        'KS': 'Kansas',
        'KY': 'Kentucky',
        'LA': 'Louisiana',
        'MA': 'Massachusetts',
        'MD': 'Maryland',
        'ME': 'Maine',
        'MI': 'Michigan',
        'MN': 'Minnesota',
        'MO': 'Missouri',
        'MP': 'Northern Mariana Islands',
        'MS': 'Mississippi',
        'MT': 'Montana',
        'NA': 'National',
        'NC': 'North Carolina',
        'ND': 'North Dakota',
        'NE': 'Nebraska',
        'NH': 'New Hampshire',
        'NJ': 'New Jersey',
        'NM': 'New Mexico',
        'NV': 'Nevada',
        'NY': 'New York',
        'OH': 'Ohio',
        'OK': 'Oklahoma',
        'OR': 'Oregon',
        'PA': 'Pennsylvania',
        'PR': 'Puerto Rico',
        'RI': 'Rhode Island',
        'SC': 'South Carolina',
        'SD': 'South Dakota',
        'TN': 'Tennessee',
        'TX': 'Texas',
        'UT': 'Utah',
        'VA': 'Virginia',
        'VI': 'Virgin Islands',
        'VT': 'Vermont',
        'WA': 'Washington',
        'WI': 'Wisconsin',
        'WV': 'West Virginia',
        'WY': 'Wyoming'
    }
    states1 = dict()
    for k,v in states.items():
     #   type(v)
        states1[v] = k
    #A dictionary to keep the sentiment for each State
    counts = dict()
    sum = 0

    for line in tweet_file:# reading tweets
        js = json.loads(line)# converting the json file to a a python data structure
        #location =js["Users"]["location"]
        #text = js["text"]
        #location =js["user"]["location"]
        # using try/except incase thers no text field or no location
        try:
            text = js["text"]#accessing the dictionary element text
            #lang = js["lang"] = "en"
            location =js["user"]["location"]# accesing the cdictoinary elemnt location inside the user
            print location
            location1,state = location.split(",")# geting the state
            #print location1
            wordslst = text.split()# geting the words in the text
            sum = 0
            #print "y"
            for words in wordslst:# looping through the words

                if state == 'India':# checking if it is in the US

                      
                    #counts[state] = counts[state] + scores
                    #ab = states1[location]
                    #print "yes"
                    #location2 = states1[location1]
                    counts[location1] = counts.get(location1,0) + scores.get(words,0)# adding the sentiment of the words and updating it into the counts
                    #dictionary using ".get" which will return zero as specified here if the state is no i counts ,if its theres it will
                    ## update the sentiment value
                    #print "yes"
                    #sum = sum + scores[words]
                #except:
                    #sum =sum +0
                   # scores[words] = sum
               # print count.items()
        except:
            sum = sum +1# nothing

    #print sum
    s = list()# a temp list to sort the counts according to values instead of keys
    for k,v in counts.items():# getting the tuples from the dic and appending them to the dic
        s.append((v,k))
        #print k,v
    s.sort(reverse=True)# sorting in reverse order so the highest comes first
    #for v,k in s[:1]:# looping through the list

        #ke = k.encode('utf-8')
       # print k,v
    for k,v in s[0:1]:
        print v,k

    #v,k = s[0]# getting the happiest state and its sentiment value

    #print k,v # printing as specified

if __name__ == '__main__':


    main()
# Out:
# Enter the state:k
#
#
#
# ‏​‏​‏​‏​‏​‏​‏​
#
# Khulna,Bangladesh
# North Little Rock
#
#
#
# with YO bitch !
#
# Twitter
#
# Santo André
# bursa
#
# Abilene, TX
# Manaus-AM
# 静岡時々大阪
#
#
#
# chains
# London
# Buenos Aires, Argentina
#
# bby
# solene  #c
# Dünya
#
#
#
#
#
# つ山口県
#
# Guatemala
#
# 魂はタワーズ天神に、精神は佐伯ビルに・・・！
#
# Italia
# Cachoeirinha/RS
#
# harlingen, tx
# Eagle Idaho
# Colombia,atlantico
# California
# La Banda, Santiago del Estero.
#
# ソウルに別荘建てる
# Minas Gerais, Brasil
# Bossier City, LA
# Japan
#
# Curitiba
# Louisville, KY
# Hill Balley, Santiago de Chile
#
#
#
# Barcelona
# Nigeria
# United Kingdom
#  Ecuador , guayaquil
#
#
# Texas
# Amo a Thallita ❤
#
# Perpignan
# Rio de Janeiro
# New York, NY
#
# Weymouth Dorset
#
#
#
# Coimbra, Portugal
#
# New York
#
# Peru
# ANKARA /MAMAK
#
# 遠い過去
#
#
# Marina del Rey, California
# River City (Fitchburg, MA)
#
#
# Краснодар
#
# Glasgow Scotland
#
# Россия
# Chiapas, México
# Rio de Janeiro, Brasil
# YAMAGATA        　JAPAN
#  USA.
#
# ...
